# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/FabulousErin/Project_2/main/static/data/yield_data.csv')
df.head()
# Out:
#   Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN     BARLEY
# 1               0        NaN      BEANS
# 2               0        NaN     CANOLA
# ...

# %%
df = df.drop(["State ANSI", "Ag District", "Ag District Code", "County", "Zip Code", "Watershed", "CV (%)"], axis=1)

# %%
df.head()
# Out:
#   Program  Year Period  Week Ending Geo Level     State  County ANSI  Region  \
# 0  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL          NaN     NaN
# 1  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL          NaN     NaN
# 2  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL          NaN     NaN
# 3  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL          NaN     NaN
# 4  SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL          NaN     NaN
#
#    watershed_code  Commodity  \
# 0               0     BARLEY
# 1               0      BEANS
# 2               0     CANOLA
# 3               0  CHICKPEAS
# 4               0       CORN
#
#                                            Data Item Domain Domain Category  \
# 0              BARLEY - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED
# 1  BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - YIELD, M...  TOTAL   NOT SPECIFIED
# 2              CANOLA - YIELD, MEASURED IN LB / ACRE  TOTAL   NOT SPECIFIED
# ...

# %%
df_Yield_Columndrops = df.drop(["Week Ending", "Program", "Period", "Geo Level", "County ANSI", "Region", "Domain", "Domain Category", "watershed_code"], axis=1)

# %%
df_Yield_Columndrops
# Out:
#       Year     State   Commodity  \
# 0     2020  US TOTAL      BARLEY
# 1     2020  US TOTAL       BEANS
# 2     2020  US TOTAL      CANOLA
# 3     2020  US TOTAL   CHICKPEAS
# 4     2020  US TOTAL        CORN
# ...    ...       ...         ...
# 3911  2010   WYOMING      BARLEY
# 3912  2010   WYOMING        CORN
# 3913  2010   WYOMING        OATS
# 3914  2010   WYOMING  SUGARBEETS
# 3915  2010   WYOMING       WHEAT
#
#                                               Data Item  Value
# 0                 BARLEY - YIELD, MEASURED IN BU / ACRE   77.5
# 1     BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - YIELD, M...  1,966
# 2                 CANOLA - YIELD, MEASURED IN LB / ACRE  1,931
# 3              CHICKPEAS - YIELD, MEASURED IN LB / ACRE  1,625
# 4            CORN, GRAIN - YIELD, MEASURED IN BU / ACRE    172
# ...                                                 ...    ...
# 3911              BARLEY - YIELD, MEASURED IN BU / ACRE     98
# ...

# %%
yield_cleaned = df_Yield_Columndrops

# %%
yield_cleaned.head()
# Out:
#    Year     State  Commodity  \
# 0  2020  US TOTAL     BARLEY
# 1  2020  US TOTAL      BEANS
# 2  2020  US TOTAL     CANOLA
# 3  2020  US TOTAL  CHICKPEAS
# 4  2020  US TOTAL       CORN
#
#                                            Data Item  Value
# 0              BARLEY - YIELD, MEASURED IN BU / ACRE   77.5
# 1  BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - YIELD, M...  1,966
# 2              CANOLA - YIELD, MEASURED IN LB / ACRE  1,931
# 3           CHICKPEAS - YIELD, MEASURED IN LB / ACRE  1,625
# 4         CORN, GRAIN - YIELD, MEASURED IN BU / ACRE    172
