# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/FabulousErin/Project_2/main/static/data/crop_area_data.csv')
df.head()
# Out:
#   Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0  SURVEY  2021   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1  SURVEY  2021   YEAR          NaN     STATE   ALABAMA         1.0
# 2  SURVEY  2021   YEAR          NaN     STATE    ALASKA         2.0
# 3  SURVEY  2021   YEAR          NaN     STATE   ARIZONA         4.0
# 4  SURVEY  2021   YEAR          NaN     STATE  ARKANSAS         5.0
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed          Commodity  \
# 0               0        NaN  FIELD CROP TOTALS
# 1               0        NaN  FIELD CROP TOTALS
# ...

# %%
df = df.drop (["Program", "Period", "Week Ending", "Geo Level", "State ANSI", "Ag District", "Ag District Code", "County", "County ANSI", "Zip Code", "Region", "watershed_code", "Watershed", "Domain", "Domain Category", "CV (%)"], axis=1)

# %%
df.head()
# Out:
#    Year     State          Commodity  \
# 0  2021  US TOTAL  FIELD CROP TOTALS
# 1  2021   ALABAMA  FIELD CROP TOTALS
# 2  2021    ALASKA  FIELD CROP TOTALS
# 3  2021   ARIZONA  FIELD CROP TOTALS
# 4  2021  ARKANSAS  FIELD CROP TOTALS
#
#                                            Data Item        Value
# 0  FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ...  316,164,000
# 1  FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ...    2,190,000
# 2  FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ...       29,000
# 3  FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ...      571,000
# 4  FIELD CROP TOTALS, PRINCIPAL, INCL POTATOES - ...    6,986,000

# %%
df = df[['State', 'Value']]

# %%
df.head()
# Out:
#       State        Value
# 0  US TOTAL  316,164,000
# 1   ALABAMA    2,190,000
# 2    ALASKA       29,000
# 3   ARIZONA      571,000
# 4  ARKANSAS    6,986,000

# %%
df
# Out:
#              State        Value
# 0         US TOTAL  316,164,000
# 1          ALABAMA    2,190,000
# 2           ALASKA       29,000
# 3          ARIZONA      571,000
# 4         ARKANSAS    6,986,000
# ..             ...          ...
# 603       VIRGINIA    2,774,000
# 604     WASHINGTON    3,681,000
# 605  WEST VIRGINIA      695,000
# 606      WISCONSIN    7,864,000
# 607        WYOMING    1,619,000
#
# [608 rows x 2 columns]
