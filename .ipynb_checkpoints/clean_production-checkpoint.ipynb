# %%
import pandas as pd

# %%
csv_path='production_data.csv'

# %%
production_df = pd.read_csv(csv_path)

production_df
# Out:
#      Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0     SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1     SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2     SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3     SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4     SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# ...      ...   ...    ...          ...       ...       ...         ...
# 1969  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 1970  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 1971  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 1972  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 1973  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
#
#       Ag District  Ag District Code  County  ...  Zip Code  Region  \
# ...

# %%
col_df= production_df.drop(columns=['Week Ending','State ANSI','Ag District','Ag District Code','County','County ANSI','Zip Code','Region','Domain Category','watershed_code','Watershed', 'CV (%)'])
col_df
# Out:
#      Program  Year Period Geo Level     State           Commodity  \
# 0     SURVEY  2020   YEAR  NATIONAL  US TOTAL  ALCOHOL COPRODUCTS
# 1     SURVEY  2020   YEAR  NATIONAL  US TOTAL  ALCOHOL COPRODUCTS
# 2     SURVEY  2020   YEAR  NATIONAL  US TOTAL  ALCOHOL COPRODUCTS
# 3     SURVEY  2020   YEAR  NATIONAL  US TOTAL  ALCOHOL COPRODUCTS
# 4     SURVEY  2020   YEAR  NATIONAL  US TOTAL  ALCOHOL COPRODUCTS
# ...      ...   ...    ...       ...       ...                 ...
# 1969  SURVEY  2020   YEAR     STATE   WYOMING               WHEAT
# 1970  SURVEY  2020   YEAR     STATE   WYOMING               WHEAT
# 1971  SURVEY  2020   YEAR     STATE   WYOMING               WHEAT
# 1972  SURVEY  2020   YEAR     STATE   WYOMING               WHEAT
# 1973  SURVEY  2020   YEAR     STATE   WYOMING               WHEAT
#
#                                               Data Item             Domain  \
# 0     ALCOHOL COPRODUCTS, CORN DISTILLERS OIL (CDO) ...  TYPE OF OPERATION
# ...

# %%
clean_df=col_df[col_df['Data Item'].str.contains('MEASURED IN \$')]
clean_df
# Out:
#      Program  Year Period Geo Level     State      Commodity  \
# 10    SURVEY  2020   YEAR  NATIONAL  US TOTAL         BARLEY
# 12    SURVEY  2020   YEAR  NATIONAL  US TOTAL          BEANS
# 33    SURVEY  2020   YEAR  NATIONAL  US TOTAL         CANOLA
# 35    SURVEY  2020   YEAR  NATIONAL  US TOTAL      CHICKPEAS
# 37    SURVEY  2020   YEAR  NATIONAL  US TOTAL      CHICKPEAS
# ...      ...   ...    ...       ...       ...            ...
# 1964  SURVEY  2020   YEAR     STATE   WYOMING  HAY & HAYLAGE
# 1965  SURVEY  2020   YEAR     STATE   WYOMING  HAY & HAYLAGE
# 1966  SURVEY  2020   YEAR     STATE   WYOMING  HAY & HAYLAGE
# 1968  SURVEY  2020   YEAR     STATE   WYOMING          WHEAT
# 1970  SURVEY  2020   YEAR     STATE   WYOMING          WHEAT
#
#                                               Data Item Domain          Value
# 10                   BARLEY - PRODUCTION, MEASURED IN $  TOTAL    753,314,000
# ...
