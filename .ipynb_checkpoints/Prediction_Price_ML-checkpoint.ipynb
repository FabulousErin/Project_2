# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import iexfinance
from iexfinance.stocks import get_historical_data
from datetime import datetime, date

# %%
#pip install iexfinance

# %%
price_df=pd.read_csv("static/data/BBG_price_data.csv")
price_df
# Out:
#           Date  Corn Price  Wheat Price  Soybean Price  Cotton Price  \
# 0     1/4/2010      418.50       557.75        1049.50         76.00
# 1     1/5/2010      418.75       553.00        1052.25         73.12
# 2     1/6/2010      421.75       567.25        1050.50         73.55
# 3     1/7/2010      417.50       557.75        1017.75         72.89
# 4     1/8/2010      423.00       568.50        1013.00         72.44
# ...        ...         ...          ...            ...           ...
# 2896  7/2/2021      697.25       645.75        1451.75         86.03
# 2897  7/6/2021      656.00       620.00        1363.75         86.38
# 2898  7/7/2021      652.50       614.75        1386.50         86.63
# 2899  7/8/2021      638.00       612.25        1390.25         85.88
# 2900  7/9/2021      629.75       608.50        1404.00         87.99
#
#       Live Cattle
# 0          85.375
# 1          86.325
# 2          85.950
# 3          85.925
# 4          85.825
# ...           ...
# 2896      122.000
# 2897      122.400
# 2898      120.600
# 2899      119.275
# 2900      119.225
#
# [2901 rows x 6 columns]

# %%
price_df.dtypes
# Out:
# Date              object
# Corn Price       float64
# Wheat Price      float64
# Soybean Price    float64
# Cotton Price     float64
# Live Cattle      float64
# dtype: object

# %%
price_df["Date"]=pd.to_datetime(price_df.Date,format='%m/%d/%Y')

# %%
price_df.dtypes
# Out:
# Date             datetime64[ns]
# Corn Price              float64
# Wheat Price             float64
# Soybean Price           float64
# Cotton Price            float64
# Live Cattle             float64
# dtype: object

# %%
price_df
# Out:
#            Date  Corn Price  Wheat Price  Soybean Price  Cotton Price  \
# 0    2010-01-04      418.50       557.75        1049.50         76.00
# 1    2010-01-05      418.75       553.00        1052.25         73.12
# 2    2010-01-06      421.75       567.25        1050.50         73.55
# 3    2010-01-07      417.50       557.75        1017.75         72.89
# 4    2010-01-08      423.00       568.50        1013.00         72.44
# ...         ...         ...          ...            ...           ...
# 2896 2021-07-02      697.25       645.75        1451.75         86.03
# 2897 2021-07-06      656.00       620.00        1363.75         86.38
# 2898 2021-07-07      652.50       614.75        1386.50         86.63
# 2899 2021-07-08      638.00       612.25        1390.25         85.88
# 2900 2021-07-09      629.75       608.50        1404.00         87.99
#
#       Live Cattle
# 0          85.375
# 1          86.325
# 2          85.950
# 3          85.925
# 4          85.825
# ...           ...
# 2896      122.000
# 2897      122.400
# 2898      120.600
# 2899      119.275
# 2900      119.225
#
# [2901 rows x 6 columns]

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Corn Price"],label='Close Price history')
plt.title("Corn Price")
# Out:
# Text(0.5, 1.0, 'Corn Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Wheat Price"],label='Close Price history')
plt.title("Wheat Price")
# Out:
# Text(0.5, 1.0, 'Wheat Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Soybean Price"],label='Close Price history')
plt.title("Soybean Price")
# Out:
# Text(0.5, 1.0, 'Soybean Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Cotton Price"],label='Close Price history')
plt.title("Cotton Price")
# Out:
# Text(0.5, 1.0, 'Cotton Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Live Cattle"],label='Close Price history')
plt.title("Live Cattle Price")
# Out:
# Text(0.5, 1.0, 'Live Cattle Price')

# %%
corn_df= price_df.drop(columns=['Soybean Price','Wheat Price','Cotton Price', 'Live Cattle'])
corn_df["Corn Price Lag"]= corn_df['Corn Price'].shift(2)
corn_df.dropna(inplace=True)
corn_df
# Out:
#            Date  Corn Price  Corn Price Lag
# 2    2010-01-06      421.75          418.50
# 3    2010-01-07      417.50          418.75
# 4    2010-01-08      423.00          421.75
# 5    2010-01-11      422.50          417.50
# 6    2010-01-12      392.50          423.00
# ...         ...         ...             ...
# 2896 2021-07-02      697.25          720.00
# 2897 2021-07-06      656.00          719.75
# 2898 2021-07-07      652.50          697.25
# 2899 2021-07-08      638.00          656.00
# 2900 2021-07-09      629.75          652.50
#
# [2899 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
corn_dataset = corn_df.values
X = corn_dataset[:,2].reshape(-1,1)
Y = corn_dataset[:,1:2]
print(X)
print(Y)
# Out:
# [[418.5]
#  [418.75]
#  [421.75]
#  ...
#  [697.25]
#  [656.0]
#  [652.5]]
# [[421.75]
#  [417.5]
#  [423.0]
#  ...
#  [652.5]
#  [638.0]
#  [629.75]]

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,test_size=0.33, random_state=1)

# %%
#test models option

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_squared_error

# %%
# wheat_df= price_df.drop(columns=['Soybean Price','Corn Price','Cotton Price', 'Live Cattle'])
# wheat_df

# %%
# soy_df= price_df.drop(columns=['Corn Price','Wheat Price','Cotton Price', 'Live Cattle'])
# soy_df

# %%
# cotton_df= price_df.drop(columns=['Soybean Price','Wheat Price','Corn Price', 'Live Cattle'])
# cotton_df

# %%
# cattle_df= price_df.drop(columns=['Soybean Price','Wheat Price','Cotton Price', 'Corn Price'])
# cattle_df

# %%
model = LinearRegression()
# Fit to model
model.fit(X_train, Y_train)
# predict
predictions = model.predict(X)
print(mean_squared_error(Y, predictions))

# %matplotlib inline 
fig= plt.figure(figsize=(24,12))

plt.scatter(Y,predictions)
plt.xlabel("Price Actual")
plt.ylabel("Predicted Price)")
plt.title("Price Forecast Based on Previous Price")
# Out:
# 178.22934891990516
# Text(0.5, 1.0, 'Price Forecast Based on Previous Price')

# %%
# Using sklearn
from sklearn.metrics import r2_score
print (r2_score(Y, predictions))
# Out:
# 0.9907610507624761

# %%
cornyCattle_df=price_df.drop(columns=['Soybean Price','Wheat Price','Cotton Price'])

# %%
cornyCattle_df["Corn Price Lag"]= corn_df['Corn Price'].shift(2)
cornyCattle_df.dropna(inplace=True)
cornyCattle_df
# Out:
#            Date  Corn Price  Live Cattle  Corn Price Lag
# 4    2010-01-08      423.00       85.825          421.75
# 5    2010-01-11      422.50       85.050          417.50
# 6    2010-01-12      392.50       85.450          423.00
# 7    2010-01-13      384.00       85.700          422.50
# 8    2010-01-14      381.00       86.650          392.50
# ...         ...         ...          ...             ...
# 2896 2021-07-02      697.25      122.000          720.00
# 2897 2021-07-06      656.00      122.400          719.75
# 2898 2021-07-07      652.50      120.600          697.25
# 2899 2021-07-08      638.00      119.275          656.00
# 2900 2021-07-09      629.75      119.225          652.50
#
# [2897 rows x 4 columns]

# %%
# cornyCattle_dataset = cornyCattle_df.values
X = cornyCattle_dataset[:,3].reshape(-1,1)
Y = cornyCattle_dataset[:,2]
print(X)
print(Y)
# Out:
# [[421.75]
#  [417.5]
#  [423.0]
#  ...
#  [697.25]
#  [656.0]
#  [652.5]]
# [85.825 85.05 85.45 ... 120.6 119.275 119.225]

# %%
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,test_size=0.33, random_state=1)

# %%
model = LinearRegression()
# Fit to model
model.fit(X_train, Y_train)
# predict
predictions = model.predict(X)
print(mean_squared_error(Y, predictions))

# %matplotlib inline 
fig= plt.figure(figsize=(24,12))

plt.scatter(Y,predictions)
plt.xlabel("Price Actual")
plt.ylabel("Price Predicted)")
plt.title("Price Forecast Based on Previous Price")
# Out:
# 296.8425513685049
# Text(0.5, 1.0, 'Price Forecast Based on Previous Price')

# %%
model = Lasso()
# Fit to model
model.fit(X_train, Y_train)
# predict
predictions = model.predict(X)
train_score=model.score(X_train,Y_train)
test_score=model.score(X_validation,Y_validation)
coeff_used = np.sum(model.coef_!=0)
print ("training score:", train_score) 
print ("test score: ", test_score)
print ("number of features used: ", coeff_used)


# # %matplotlib inline 
# fig= plt.figure(figsize=(24,12))

# plt.scatter(Y,predictions)
# plt.xlabel("Price Forecast")
# plt.ylabel("Previous Price (2 Days)")
# plt.title("Price Forecast Based on Previous Price")
# Out:
# training score: 6.76962456036545e-06
# test score:  -0.0016215532288739176
# number of features used:  1
