# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import iexfinance
from iexfinance.stocks import get_historical_data
from datetime import datetime, date

# %%
#pip install iexfinance
#!pip install seaborn

# %%
price_df=pd.read_csv("static/data/BBG_price_data.csv")
price_df
# Out:
#         Date  Corn Price  Wheat Price  Soybean Price  Cotton Price  \
# 0     1/4/10      418.50       557.75        1049.50         76.00
# 1     1/5/10      418.75       553.00        1052.25         73.12
# 2     1/6/10      421.75       567.25        1050.50         73.55
# 3     1/7/10      417.50       557.75        1017.75         72.89
# 4     1/8/10      423.00       568.50        1013.00         72.44
# ...      ...         ...          ...            ...           ...
# 2896  7/2/21      697.25       645.75        1451.75         86.03
# 2897  7/6/21      656.00       620.00        1363.75         86.38
# 2898  7/7/21      652.50       614.75        1386.50         86.63
# 2899  7/8/21      638.00       612.25        1390.25         85.88
# 2900  7/9/21      629.75       608.50        1404.00         87.99
#
#       Live Cattle  Soy Oil  Crush Margin  Soybean meal
# 0          85.375    37.73           NaN           NaN
# 1          86.325    37.54           NaN           NaN
# 2          85.950    37.70           NaN           NaN
# 3          85.925    36.62          0.99         326.5
# 4          85.825    36.49           NaN           NaN
# ...           ...      ...           ...           ...
# 2896      122.000      NaN           NaN           NaN
# 2897      122.400    71.12           NaN           NaN
# 2898      120.600      NaN           NaN           NaN
# 2899      119.275      NaN          3.12         362.1
# 2900      119.225      NaN           NaN           NaN
#
# [2901 rows x 9 columns]

# %%
price_df.dtypes
# Out:
# Date              object
# Corn Price       float64
# Wheat Price      float64
# Soybean Price    float64
# Cotton Price     float64
# Live Cattle      float64
# Soy Oil          float64
# Crush Margin     float64
# Soybean meal     float64
# dtype: object

# %%
price_df["Date"]=pd.to_datetime(price_df.Date,format='%m/%d/%y')

# %%
price_df.dtypes
# Out:
# Date             datetime64[ns]
# Corn Price              float64
# Wheat Price             float64
# Soybean Price           float64
# Cotton Price            float64
# Live Cattle             float64
# Soy Oil                 float64
# Crush Margin            float64
# Soybean meal            float64
# dtype: object

# %%
price_df
# Out:
#            Date  Corn Price  Wheat Price  Soybean Price  Cotton Price  \
# 0    2010-01-04      418.50       557.75        1049.50         76.00
# 1    2010-01-05      418.75       553.00        1052.25         73.12
# 2    2010-01-06      421.75       567.25        1050.50         73.55
# 3    2010-01-07      417.50       557.75        1017.75         72.89
# 4    2010-01-08      423.00       568.50        1013.00         72.44
# ...         ...         ...          ...            ...           ...
# 2896 2021-07-02      697.25       645.75        1451.75         86.03
# 2897 2021-07-06      656.00       620.00        1363.75         86.38
# 2898 2021-07-07      652.50       614.75        1386.50         86.63
# 2899 2021-07-08      638.00       612.25        1390.25         85.88
# 2900 2021-07-09      629.75       608.50        1404.00         87.99
#
#       Live Cattle  Soy Oil  Crush Margin  Soybean meal
# 0          85.375    37.73           NaN           NaN
# 1          86.325    37.54           NaN           NaN
# 2          85.950    37.70           NaN           NaN
# 3          85.925    36.62          0.99         326.5
# 4          85.825    36.49           NaN           NaN
# ...           ...      ...           ...           ...
# 2896      122.000      NaN           NaN           NaN
# 2897      122.400    71.12           NaN           NaN
# 2898      120.600      NaN           NaN           NaN
# 2899      119.275      NaN          3.12         362.1
# 2900      119.225      NaN           NaN           NaN
#
# [2901 rows x 9 columns]

# %%
plt.figure(figsize=(16,8))
y1=price_df["Corn Price"]
x1=price_df["Date"]
y2 =price_df["Wheat Price"]
y3 =price_df["Soybean Price"]
plt.plot(x1, y1,label='Corn')
plt.plot(x1, y2,label='Wheat')
plt.plot(x1, y3,label='Soybean')
plt.title("Corn, Wheat, Soybean Prices",fontsize=40, backgroundcolor='white')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
ax.set_facecolor('#FFFFFF')
plt.ylabel('Price',fontsize=30)
plt.legend(fontsize=25)
corn_and_wheat = 'static/data/Corn, Wheat, Soybean Prices.png'
plt.savefig(corn_and_wheat)
print(corn_and_wheat)
# Out:
# static/data/Corn, Wheat, Soybean Prices.png

# %%
# plt.figure(figsize=(16,8))
# plt.plot(price_df["Wheat Price"],label='Close Price history')
# plt.title("Wheat Price")
# Out:
# Text(0.5, 1.0, 'Wheat Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Soybean Price"],label='Close Price history')
plt.title("Soybean Price")
# Out:
# Text(0.5, 1.0, 'Soybean Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Cotton Price"],label='Close Price history')
plt.title("Cotton Price")
# Out:
# Text(0.5, 1.0, 'Cotton Price')

# %%
plt.figure(figsize=(16,8))
plt.plot(price_df["Live Cattle"],label='Close Price history')
plt.title("Live Cattle Price")
# Out:
# Text(0.5, 1.0, 'Live Cattle Price')

# %%
corn_df= price_df.drop(columns=['Soy Oil', 'Crush Margin', 'Soybean meal','Soybean Price','Wheat Price','Cotton Price', 'Live Cattle'])
corn_df["Corn Price Lag 1"]= corn_df['Corn Price'].shift(1)
corn_df["Corn Price Lag 5"]= corn_df['Corn Price'].shift(5)
corn_df["Corn Price Lag 10"]= corn_df['Corn Price'].shift(10)
corn_df["Corn Price Lag 20"]= corn_df['Corn Price'].shift(20)
corn_df["Corn Price Up-Down"]= (corn_df['Corn Price Lag 1']>corn_df['Corn Price']).astype(int)
corn_df.dropna(inplace=True)
corn_df
# Out:
#            Date  Corn Price  Corn Price Lag 1  Corn Price Lag 5  \
# 20   2010-02-02      365.00            359.00            362.25
# 21   2010-02-03      353.00            365.00            358.25
# 22   2010-02-04      354.00            353.00            361.75
# 23   2010-02-05      351.50            354.00            356.50
# 24   2010-02-08      356.00            351.50            359.00
# ...         ...         ...               ...               ...
# 2896 2021-07-02      697.25            719.75            636.50
# 2897 2021-07-06      656.00            697.25            675.50
# 2898 2021-07-07      652.50            656.00            694.50
# 2899 2021-07-08      638.00            652.50            720.00
# 2900 2021-07-09      629.75            638.00            719.75
#
#       Corn Price Lag 10  Corn Price Lag 20  Corn Price Up-Down
# 20               369.25             418.50                   0
# 21               368.00             418.75                   1
# 22               372.00             421.75                   0
# 23               364.75             417.50                   1
# 24               367.75             423.00                   0
# ...                 ...                ...                 ...
# 2896             655.25             682.75                   1
# 2897             659.25             679.25                   1
# 2898             659.75             680.00                   1
# 2899             664.25             690.75                   1
# 2900             653.25             699.00                   1
#
# [2881 rows x 7 columns]

# %%
wheat_df= price_df.drop(columns=['Soy Oil', 'Crush Margin', 'Soybean meal','Soybean Price','Corn Price','Cotton Price', 'Live Cattle'])
wheat_df["Wheat Price Lag 1"]= wheat_df['Wheat Price'].shift(1)
wheat_df["Wheat Price Lag 5"]= wheat_df['Wheat Price'].shift(5)
wheat_df["Wheat Price Lag 10"]= wheat_df['Wheat Price'].shift(10)
wheat_df["Wheat Price Lag 20"]= wheat_df['Wheat Price'].shift(20)
wheat_df["Wheat Price Up-Down"]= (wheat_df['Wheat Price Lag 1']>wheat_df['Wheat Price']).astype(int)
wheat_df.dropna(inplace=True)
wheat_df
# Out:
#            Date  Wheat Price  Wheat Price Lag 1  Wheat Price Lag 5  \
# 20   2010-02-02       487.25             474.75             494.00
# 21   2010-02-03       469.00             487.25             483.75
# 22   2010-02-04       475.75             469.00             487.00
# 23   2010-02-05       473.25             475.75             474.00
# 24   2010-02-08       484.00             473.25             474.75
# ...         ...          ...                ...                ...
# 2896 2021-07-02       645.75             658.50             637.00
# 2897 2021-07-06       620.00             645.75             646.00
# 2898 2021-07-07       614.75             620.00             639.75
# 2899 2021-07-08       612.25             614.75             671.50
# 2900 2021-07-09       608.50             612.25             658.50
#
#       Wheat Price Lag 10  Wheat Price Lag 20  Wheat Price Up-Down
# 20                500.50              557.75                    0
# 21                497.50              553.00                    1
# 22                499.50              567.25                    0
# 23                498.50              557.75                    1
# 24                498.25              568.50                    0
# ...                  ...                 ...                  ...
# 2896              662.75              687.75                    1
# 2897              661.50              680.00                    1
# 2898              651.00              685.00                    1
# 2899              661.25              682.25                    1
# 2900              651.25              683.75                    1
#
# [2881 rows x 7 columns]

# %%
soybean_df= price_df.drop(columns=['Soy Oil', 'Crush Margin', 'Soybean meal','Wheat Price','Corn Price','Cotton Price', 'Live Cattle'])
soybean_df["Soybean Price Lag 1"]= soybean_df['Soybean Price'].shift(1)
soybean_df["Soybean Price Lag 5"]= soybean_df['Soybean Price'].shift(5)
soybean_df["Soybean Price Lag 10"]= soybean_df['Soybean Price'].shift(10)
soybean_df["Soybean Price Lag 20"]= soybean_df['Soybean Price'].shift(20)
soybean_df["Soybean Price Up-Down"]= (soybean_df['Soybean Price Lag 1']>soybean_df['Soybean Price']).astype(int)
soybean_df.dropna(inplace=True)
soybean_df
# Out:
#            Date  Soybean Price  Soybean Price Lag 1  Soybean Price Lag 5  \
# 20   2010-02-02         925.50               909.75               947.50
# 21   2010-02-03         908.00               925.50               929.00
# 22   2010-02-04         914.00               908.00               931.75
# 23   2010-02-05         913.50               914.00               914.00
# 24   2010-02-08         929.50               913.50               909.75
# ...         ...            ...                  ...                  ...
# 2896 2021-07-02        1451.75              1446.75              1329.75
# 2897 2021-07-06        1363.75              1451.75              1357.00
# 2898 2021-07-07        1386.50              1363.75              1359.75
# 2899 2021-07-08        1390.25              1386.50              1450.00
# 2900 2021-07-09        1404.00              1390.25              1446.75
#
#       Soybean Price Lag 10  Soybean Price Lag 20  Soybean Price Up-Down
# 20                  963.50               1049.50                      0
# 21                  950.00               1052.25                      1
# 22                  954.00               1050.50                      0
# 23                  951.50               1017.75                      1
# 24                  940.50               1013.00                      0
# ...                    ...                   ...                    ...
# 2896               1396.00               1583.75                      0
# 2897               1415.00               1560.25                      1
# 2898               1394.50               1580.00                      0
# 2899               1385.00               1562.50                      0
# 2900               1371.25               1544.00                      0
#
# [2881 rows x 7 columns]

# %%
cotton_df= price_df.drop(columns=['Soy Oil', 'Crush Margin', 'Soybean meal','Wheat Price','Corn Price','Soybean Price', 'Live Cattle'])
cotton_df["Cotton Price Lag 1"]= cotton_df['Cotton Price'].shift(1)
cotton_df["Cotton Price Lag 5"]= cotton_df['Cotton Price'].shift(5)
cotton_df["Cotton Price Lag 10"]= cotton_df['Cotton Price'].shift(10)
cotton_df["Cotton Price Lag 20"]= cotton_df['Cotton Price'].shift(20)
cotton_df["Cotton Price Up-Down"]= (cotton_df['Cotton Price Lag 1']>cotton_df['Cotton Price']).astype(int)
cotton_df.dropna(inplace=True)
cotton_df
# Out:
#            Date  Cotton Price  Cotton Price Lag 1  Cotton Price Lag 5  \
# 20   2010-02-02         69.26               68.22               69.82
# 21   2010-02-03         69.82               69.26               69.23
# 22   2010-02-04         68.99               69.82               69.14
# 23   2010-02-05         66.62               68.99               69.03
# 24   2010-02-08         69.16               66.62               68.22
# ...         ...           ...                 ...                 ...
# 2896 2021-07-02         86.03               85.01               86.43
# 2897 2021-07-06         86.38               86.03               86.66
# 2898 2021-07-07         86.63               86.38               86.49
# 2899 2021-07-08         85.88               86.63               84.03
# 2900 2021-07-09         87.99               85.88               85.01
#
#       Cotton Price Lag 10  Cotton Price Lag 20  Cotton Price Up-Down
# 20                  71.64                76.00                     0
# 21                  70.80                73.12                     0
# 22                  71.85                73.55                     1
# 23                  71.07                72.89                     1
# 24                  69.96                72.44                     0
# ...                   ...                  ...                   ...
# 2896                84.42                85.80                     0
# 2897                84.09                84.36                     0
# 2898                84.22                85.14                     0
# 2899                86.46                86.62                     1
# 2900                86.03                87.36                     0
#
# [2881 rows x 7 columns]

# %%
cattle_df= price_df.drop(columns=['Soy Oil', 'Crush Margin', 'Soybean meal','Wheat Price','Corn Price','Soybean Price', 'Cotton Price'])
cattle_df["Live Cattle Price Lag 1"]= cattle_df['Live Cattle'].shift(1)
cattle_df["Live Cattle Price Lag 5"]= cattle_df['Live Cattle'].shift(5)
cattle_df["Live Cattle Price Lag 10"]= cattle_df['Live Cattle'].shift(10)
cattle_df["Live Cattle Price Lag 20"]= cattle_df['Live Cattle'].shift(20)
cattle_df["Live Cattle Up-Down"]= (cattle_df['Live Cattle Price Lag 1']>cattle_df['Live Cattle']).astype(int)
cattle_df.dropna(inplace=True)
cattle_df
# Out:
#            Date  Live Cattle  Live Cattle Price Lag 1  \
# 20   2010-02-02       86.225                   85.250
# 21   2010-02-03       86.450                   86.225
# 22   2010-02-04       86.550                   86.450
# 23   2010-02-05       87.425                   86.550
# 24   2010-02-08       87.675                   87.425
# ...         ...          ...                      ...
# 2896 2021-07-02      122.000                  123.575
# 2897 2021-07-06      122.400                  122.000
# 2898 2021-07-07      120.600                  122.400
# 2899 2021-07-08      119.275                  120.600
# 2900 2021-07-09      119.225                  119.275
#
#       Live Cattle Price Lag 5  Live Cattle Price Lag 10  \
# 20                     85.525                    87.900
# 21                     85.375                    87.450
# 22                     85.650                    86.850
# 23                     85.800                    86.625
# 24                     85.250                    86.200
# ...                       ...                       ...
# 2896                  122.825                   121.050
# 2897                  122.100                   120.975
# 2898                  122.550                   123.100
# 2899                  122.500                   122.500
# 2900                  123.575                   122.825
#
#       Live Cattle Price Lag 20  Live Cattle Up-Down
# 20                      85.375                    0
# 21                      86.325                    0
# 22                      85.950                    0
# 23                      85.925                    0
# 24                      85.825                    0
# ...                        ...                  ...
# 2896                   116.825                    1
# 2897                   116.225                    0
# 2898                   116.725                    1
# 2899                   117.400                    1
# 2900                   117.575                    1
#
# [2881 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import metrics

# %%
data_frame_list =[corn_df,wheat_df, soybean_df, cotton_df, cattle_df]
commodity_list =['Corn Price','Wheat Price','Soybean Price','Cotton Price', 'Live Cattle']
price_move_list =['Corn Price Up-Down','Wheat Price Up-Down','Soybean Price Up-Down','Cotton Price Up-Down','Live Cattle Up-Down']

# %%
for x in range(len(data_frame_list)):
    X = data_frame_list[x].iloc[:,2:3]
    Y = data_frame_list[x][commodity_list[x]]
    X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,test_size=0.33, random_state=1)
    model = LinearRegression()
        # Fit to model
    model.fit(X_train, Y_train)
        # predict
    predictions = model.predict(X_validation)
    print(mean_squared_error(Y_validation, predictions))

        # %matplotlib inline 
    fig= plt.figure(figsize=(24,12))

    plt.xticks(fontsize = 30)
    plt.yticks(fontsize = 30)
    plt.scatter(Y_validation,predictions)
    plt.xlabel("Actual Price", fontsize=30)
    plt.ylabel("Predicted Price", fontsize=30)
    ax = plt.axes()
    ax.set_facecolor('#FFFFFF')
    plt.title(f"{commodity_list[x]} Forecast Based on Previous Day's Price", fontsize=40, backgroundcolor='white')
    plt.text(data_frame_list[x][commodity_list[x]].min(),predictions.max(),"r-squared = {:.3f}".format(r2_score(Y_validation, predictions)), fontsize=30)
    print(r2_score(Y_validation,predictions))
       
    path_to_save = 'static/data/' + (f'{commodity_list[x]} Based on Previous Day.png')
    plt.savefig(path_to_save)
# Out:
# 77.16179086686623
# 0.9960867125109718
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 125.30034042528703
# 0.991484017169176
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 272.13421627147477
# 0.9950094883110939
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 2.847218444335292
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 0.9955445337664597
# 1.8821070216276934
# 0.9938007120755725
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
for x in range(len(data_frame_list)):
    X = data_frame_list[x].iloc[:,3:6]
    Y = data_frame_list[x][commodity_list[x]]
    X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,test_size=0.33, random_state=1)
    model = LinearRegression()
        # Fit to model
    model.fit(X_train, Y_train)
        # predict
    predictions = model.predict(X_validation)
    print(mean_squared_error(Y_validation, predictions))

        # %matplotlib inline 
    fig= plt.figure(figsize=(24,12))

    plt.xticks(fontsize = 30)
    plt.yticks(fontsize = 30)
    plt.scatter(Y_validation,predictions)
    plt.xlabel("Actual Price", fontsize=30)
    plt.ylabel("Predicted Price", fontsize=30)
    ax = plt.axes()
    ax.set_facecolor('#FFFFFF')
    plt.title(f"{commodity_list[x]} Forecast Based on 5, 10, 20 Days", fontsize=40, backgroundcolor='white')
#     plt.rcParams['axes.facecolor'] = 'silver'
    plt.text(data_frame_list[x][commodity_list[x]].min(),predictions.max(),"r-squared = {:.3f}".format(r2_score(Y_validation, predictions)), fontsize=30)
    print(r2_score(Y_validation,predictions))
    
    custom_path = 'static/data/' + (f'{commodity_list[x]} Based on 5,10,20 Days.png')
    print(custom_path)
    
    plt.savefig(custom_path)
# Out:
# 429.621282447549
# 0.9782116048534567
# static/data/Corn Price Based on 5,10,20 Days.png
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 611.0596356079686
# 0.9584695991424708
# static/data/Wheat Price Based on 5,10,20 Days.png
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 1366.782823351522
# 0.9749353618608274
# static/data/Soybean Price Based on 5,10,20 Days.png
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 18.744295640580777
# 0.9706680123317329
# static/data/Cotton Price Based on 5,10,20 Days.png
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# 10.705219997705843
# 0.9647391246632068
# static/data/Live Cattle Based on 5,10,20 Days.png
# C:\Users\erinn\Anaconda3\envs\BootCampML\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
for x in range(len(data_frame_list)):
    X = data_frame_list[x].iloc[:,2:6]
    Y = data_frame_list[x][price_move_list[x]]
    X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y,test_size=0.33, random_state=0)
    model = LogisticRegression()
        # Fit to model
    model.fit(X_train, Y_train)
        # predict
    predictions = model.predict(X_validation)
    output = round(mean_squared_error(Y_validation, predictions),4)
    
    cm_labels = metrics.confusion_matrix(Y_validation, predictions)
    cm_data = np.array([[0,1],[1,0]])
    
    plt.figure(figsize=(9,9))
    sns.heatmap(cm_data, annot=cm_labels, fmt=".0f", linewidths=.5, square = True, cmap = 'RdYlBu_r');
    plt.ylabel('Actual Price Move: 1=Up 0=Down');
    plt.xlabel('Predicted Price Move: 1=Up 0=Down');
    all_sample_title = 'Accuracy Score: {0}'.format(model)
    plt.title(f'{price_move_list[x]}'+' Accuracy Score: '+ f'{output}', size = 15);
    
    heatmap_path = 'static/data/' + (f'{price_move_list[x]} Based on Previous Day Up-Down.png')
    print(heatmap_path)
    
    plt.savefig(heatmap_path)
# Out:
# static/data/Corn Price Up-Down Based on Previous Day Up-Down.png
# static/data/Wheat Price Up-Down Based on Previous Day Up-Down.png
# static/data/Soybean Price Up-Down Based on Previous Day Up-Down.png
# static/data/Cotton Price Up-Down Based on Previous Day Up-Down.png
# static/data/Live Cattle Up-Down Based on Previous Day Up-Down.png
