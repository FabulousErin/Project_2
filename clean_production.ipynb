# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_path='static/data/production_data_sorted.csv'

# %%
production_df = pd.read_csv(csv_path)

production_df
# Out:
#     Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0    SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 1    SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 2    SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 3    SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# 4    SURVEY  2020   YEAR          NaN  NATIONAL  US TOTAL         NaN
# ..      ...   ...    ...          ...       ...       ...         ...
# 324  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 325  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 326  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 327  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
# 328  SURVEY  2020   YEAR          NaN     STATE   WYOMING        56.0
#
#      Ag District  Ag District Code  County  ...  Zip Code  Region  \
# ...

# %%
# clean_df=col_df[col_df['Data Item'].str.contains('MEASURED IN \$')]
# clean_df

# %%
clean_df= production_df.drop(columns=['Program','Period','Week Ending','Geo Level','State ANSI','Ag District','Ag District Code','County','County ANSI','Zip Code','Region','Domain','Domain Category','watershed_code','Watershed', 'CV (%)'])
clean_df
# Out:
#      Year     State      Commodity  \
# 0    2020  US TOTAL         BARLEY
# 1    2020  US TOTAL          BEANS
# 2    2020  US TOTAL         CANOLA
# 3    2020  US TOTAL      CHICKPEAS
# 4    2020  US TOTAL           CORN
# ..    ...       ...            ...
# 324  2020   WYOMING         BARLEY
# 325  2020   WYOMING          BEANS
# 326  2020   WYOMING           CORN
# 327  2020   WYOMING  HAY & HAYLAGE
# 328  2020   WYOMING          WHEAT
#
#                                              Data Item           Value
# 0                   BARLEY - PRODUCTION, MEASURED IN $     753,314,000
# 1    BEANS, DRY EDIBLE, (EXCL CHICKPEAS) - PRODUCTI...   1,005,619,000
# 2                   CANOLA - PRODUCTION, MEASURED IN $     602,504,000
# 3                CHICKPEAS - PRODUCTION, MEASURED IN $      83,210,000
# 4              CORN, GRAIN - PRODUCTION, MEASURED IN $  61,039,005,000
# ..                                                 ...             ...
# ...

# %%
# con.execute('alter table my_table add id serial primary key')

# %%
# !pip install psycopg2

# %%
from sqlalchemy import create_engine
import psycopg2 
con_str = 'postgres:myAkina93!@database-1.c6qqzgohsabf.us-east-2.rds.amazonaws.com:5432/project2'
engine = create_engine(f'postgresql://{con_str}')

# %%
clean_df.to_sql(name='production_data', con=engine, if_exists='append', index=False)
